# %% [markdown]
# <a href="https://colab.research.google.com/github/SARAVANAN-2004/Spotify-Dataset-Analysis/blob/main/spotify_data_set_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #spotify

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("/content/drive/MyDrive/data science datas/data science day 6 spotify dataset/data.csv")

# %%
data.head()
# Out:
#    Unnamed: 0  acousticness  danceability  duration_ms  energy  \
# 0           0        0.0102         0.833       204600   0.434
# 1           1        0.1990         0.743       326933   0.359
# 2           2        0.0344         0.838       185707   0.412
# 3           3        0.6040         0.494       199413   0.338
# 4           4        0.1800         0.678       392893   0.561
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0          0.021900    2    0.1650    -8.795     1       0.4310  150.062
# 1          0.006110    1    0.1370   -10.401     1       0.0794  160.083
# 2          0.000234    2    0.1590    -7.148     1       0.2890   75.044
# 3          0.510000    5    0.0922   -15.236     1       0.0261   86.468
# 4          0.512000    5    0.4390   -11.648     0       0.0694  174.004
#
#    time_signature  valence  target      song_title            artist
# 0             4.0    0.286       1        Mask Off            Future
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2017 entries, 0 to 2016
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        2017 non-null   int64
#  1   acousticness      2017 non-null   float64
#  2   danceability      2017 non-null   float64
#  3   duration_ms       2017 non-null   int64
#  4   energy            2017 non-null   float64
#  5   instrumentalness  2017 non-null   float64
#  6   key               2017 non-null   int64
#  7   liveness          2017 non-null   float64
#  8   loudness          2017 non-null   float64
#  9   mode              2017 non-null   int64
#  10  speechiness       2017 non-null   float64
#  11  tempo             2017 non-null   float64
#  12  time_signature    2017 non-null   float64
#  13  valence           2017 non-null   float64
#  14  target            2017 non-null   int64
#  15  song_title        2017 non-null   object
# ...

# %%
data.drop(["Unnamed: 0"],axis=1,inplace=True)

# %%
data.head()
# Out:
#    acousticness  danceability  duration_ms  energy  instrumentalness  key  \
# 0        0.0102         0.833       204600   0.434          0.021900    2
# 1        0.1990         0.743       326933   0.359          0.006110    1
# 2        0.0344         0.838       185707   0.412          0.000234    2
# 3        0.6040         0.494       199413   0.338          0.510000    5
# 4        0.1800         0.678       392893   0.561          0.512000    5
#
#    liveness  loudness  mode  speechiness    tempo  time_signature  valence  \
# 0    0.1650    -8.795     1       0.4310  150.062             4.0    0.286
# 1    0.1370   -10.401     1       0.0794  160.083             4.0    0.588
# 2    0.1590    -7.148     1       0.2890   75.044             4.0    0.173
# 3    0.0922   -15.236     1       0.0261   86.468             4.0    0.230
# 4    0.4390   -11.648     0       0.0694  174.004             4.0    0.904
#
#    target      song_title            artist
# ...

# %%
data.describe()
# Out:
#        acousticness  danceability   duration_ms       energy  \
# count   2017.000000   2017.000000  2.017000e+03  2017.000000
# mean       0.187590      0.618422  2.463062e+05     0.681577
# std        0.259989      0.161029  8.198181e+04     0.210273
# min        0.000003      0.122000  1.604200e+04     0.014800
# 25%        0.009630      0.514000  2.000150e+05     0.563000
# 50%        0.063300      0.631000  2.292610e+05     0.715000
# 75%        0.265000      0.738000  2.703330e+05     0.846000
# max        0.995000      0.984000  1.004627e+06     0.998000
#
#        instrumentalness          key     liveness     loudness         mode  \
# count       2017.000000  2017.000000  2017.000000  2017.000000  2017.000000
# mean           0.133286     5.342588     0.190844    -7.085624     0.612295
# std            0.273162     3.648240     0.155453     3.761684     0.487347
# min            0.000000     0.000000     0.018800   -33.097000     0.000000
# ...

# %%
data.isnull().sum()
# Out:
# acousticness        0
# danceability        0
# duration_ms         0
# energy              0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# speechiness         0
# tempo               0
# time_signature      0
# valence             0
# target              0
# song_title          0
# artist              0
# dtype: int64

# %%
data.head()
# Out:
#    acousticness  danceability  duration_ms  energy  instrumentalness  key  \
# 0        0.0102         0.833       204600   0.434          0.021900    2
# 1        0.1990         0.743       326933   0.359          0.006110    1
# 2        0.0344         0.838       185707   0.412          0.000234    2
# 3        0.6040         0.494       199413   0.338          0.510000    5
# 4        0.1800         0.678       392893   0.561          0.512000    5
#
#    liveness  loudness  mode  speechiness    tempo  time_signature  valence  \
# 0    0.1650    -8.795     1       0.4310  150.062             4.0    0.286
# 1    0.1370   -10.401     1       0.0794  160.083             4.0    0.588
# 2    0.1590    -7.148     1       0.2890   75.044             4.0    0.173
# 3    0.0922   -15.236     1       0.0261   86.468             4.0    0.230
# 4    0.4390   -11.648     0       0.0694  174.004             4.0    0.904
#
#    target      song_title            artist
# ...

# %%
data["target"].value_counts()
# Out:
# 1    1020
# 0     997
# Name: target, dtype: int64

# %%
values = data["target"].value_counts()# saving the values in the variable

# %%
label = ['positive','negative']

# %%
plt.pie(values,labels=label,autopct="%1.1f")
# Out:
# ([<matplotlib.patches.Wedge at 0x7fcbfb1e5930>,
# ...
#  [Text(-0.01970206079978362, 1.099823544392573, 'positive'),
#   Text(0.019702060799783244, -1.099823544392573, 'negative')],
#  [Text(-0.010746578618063793, 0.5999037514868579, '50.6'),
#   Text(0.010746578618063586, -0.5999037514868579, '49.4')])

# %%
data.corr()
# Out:
# <ipython-input-59-c44ded798807>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                   acousticness  danceability  duration_ms    energy  \
# acousticness          1.000000     -0.179894     0.071536 -0.646319
# danceability         -0.179894      1.000000     0.004695  0.038557
# duration_ms           0.071536      0.004695     1.000000 -0.144473
# energy               -0.646319      0.038557    -0.144473  1.000000
# instrumentalness      0.144397     -0.130561     0.305403 -0.122890
# key                  -0.081037      0.022325     0.023570  0.072886
# liveness             -0.117126     -0.132044     0.023203  0.217435
# loudness             -0.562021      0.104362    -0.273798  0.762177
# mode                  0.068028     -0.047867    -0.074806 -0.070263
# ...

# %%
plt.figure(figsize=(10,8))
sns.heatmap(data.corr(),annot = True ,fmt=".1f",cmap="Greens_r")
# Out:
# <ipython-input-60-70758f159410>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(),annot = True ,fmt=".1f",cmap="Greens_r")
# <Axes: >

# %% [markdown]
# #what are the top 5 artist with most songs in the dataset?

# %%
data.head()
# Out:
#    acousticness  danceability  duration_ms  energy  instrumentalness  key  \
# 0        0.0102         0.833       204600   0.434          0.021900    2
# 1        0.1990         0.743       326933   0.359          0.006110    1
# 2        0.0344         0.838       185707   0.412          0.000234    2
# 3        0.6040         0.494       199413   0.338          0.510000    5
# 4        0.1800         0.678       392893   0.561          0.512000    5
#
#    liveness  loudness  mode  speechiness    tempo  time_signature  valence  \
# 0    0.1650    -8.795     1       0.4310  150.062             4.0    0.286
# 1    0.1370   -10.401     1       0.0794  160.083             4.0    0.588
# 2    0.1590    -7.148     1       0.2890   75.044             4.0    0.173
# 3    0.0922   -15.236     1       0.0261   86.468             4.0    0.230
# 4    0.4390   -11.648     0       0.0694  174.004             4.0    0.904
#
#    target      song_title            artist
# ...

# %%
data["artist"].value_counts().sort_values(ascending = False)
# Out:
# Drake              16
# Rick Ross          13
# Disclosure         12
# WALK THE MOON      10
# Backstreet Boys    10
#                    ..
# Stan Getz           1
# Ray Bryant          1
# Duke Ellington      1
# John Mayer          1
# Bleachers           1
# Name: artist, Length: 1343, dtype: int64

# %%
top5artist=data.groupby("artist").size().sort_values(ascending = False)[:5]

# %%
top5artist.index
# Out:
# Index(['Drake', 'Rick Ross', 'Disclosure', 'Backstreet Boys', 'WALK THE MOON'], dtype='object', name='artist')

# %%
top5artist.values
# Out:
# array([16, 13, 12, 10, 10])

# %%
plt.barh(top5artist.index,top5artist.values)
# Out:
# <BarContainer object of 5 artists>

# %%
sns.barplot(x= top5artist.index, y = top5artist.values)
# Out:
# <Axes: xlabel='artist'>

# %% [markdown]
# #what is the average duration of songs in dataset

# %%
data.head()
# Out:
#    acousticness  danceability  duration_ms  energy  instrumentalness  key  \
# 0        0.0102         0.833       204600   0.434          0.021900    2
# 1        0.1990         0.743       326933   0.359          0.006110    1
# 2        0.0344         0.838       185707   0.412          0.000234    2
# 3        0.6040         0.494       199413   0.338          0.510000    5
# 4        0.1800         0.678       392893   0.561          0.512000    5
#
#    liveness  loudness  mode  speechiness    tempo  time_signature  valence  \
# 0    0.1650    -8.795     1       0.4310  150.062             4.0    0.286
# 1    0.1370   -10.401     1       0.0794  160.083             4.0    0.588
# 2    0.1590    -7.148     1       0.2890   75.044             4.0    0.173
# 3    0.0922   -15.236     1       0.0261   86.468             4.0    0.230
# 4    0.4390   -11.648     0       0.0694  174.004             4.0    0.904
#
#    target      song_title            artist
# ...

# %%
avg_duration_ms = data["duration_ms"].mean()
avg_duration_min = data["duration_ms"].mean()/(1000*60)
print(f"the average duration of the songs in {avg_duration_min:.2f}  minutes")
# Out:
# the average duration of the songs in 4.11  minutes

# %%
sns.scatterplot(data["duration_ms"]/(1000*60))
# Out:
# <Axes: ylabel='duration_ms'>

# %% [markdown]
# #what is the distribution of energy levels in the dataset?are there any outlier

# %%
data.head()
# Out:
#    acousticness  danceability  duration_ms  energy  instrumentalness  key  \
# 0        0.0102         0.833       204600   0.434          0.021900    2
# 1        0.1990         0.743       326933   0.359          0.006110    1
# 2        0.0344         0.838       185707   0.412          0.000234    2
# 3        0.6040         0.494       199413   0.338          0.510000    5
# 4        0.1800         0.678       392893   0.561          0.512000    5
#
#    liveness  loudness  mode  speechiness    tempo  time_signature  valence  \
# 0    0.1650    -8.795     1       0.4310  150.062             4.0    0.286
# 1    0.1370   -10.401     1       0.0794  160.083             4.0    0.588
# 2    0.1590    -7.148     1       0.2890   75.044             4.0    0.173
# 3    0.0922   -15.236     1       0.0261   86.468             4.0    0.230
# 4    0.4390   -11.648     0       0.0694  174.004             4.0    0.904
#
#    target      song_title            artist
# ...

# %%
sns.histplot(data["energy"],bins=30)
# Out:
# <Axes: xlabel='energy', ylabel='Count'>

# %%
#inter quantile range

q1 = data["energy"].quantile(0.25)
q2 = data["energy"].quantile(0.75)

iqr= q2 - q1

# %%
iqr
# Out:
# 0.28300000000000003

# %%
outlier =  data[(data ["energy"] < q1 -1.5*iqr) | (data ["energy"] > q2 + 1.5*iqr)]

# %%
print(f" no of the outlier = {len(outlier)}")
# Out:
#  no of the outlier = 54

# %%
print(outlier["song_title"])
# Out:
# 817     Mozart: Requiem in D Minor, K. 626: VIII. Lacr...
# 921                                        I'm Going Down
# 1074                                           Either Way
# 1400                                           Let You Go
# 1512                                    I'll Let You Know
# 1513                                   I'll Wait And Pray
# 1514                             The Shadow of Your Smile
# 1515    Vid Frösö kyrka (At Frösö Church) - From Frösö...
# 1519                                Where We Used To Live
# 1521                                        For Wee Folks
# 1523                                 Goodbye Pork Pie Hat
# 1524                                        Ballad for MC
# 1526                                            So Lovely
# 1527                                The Sweetest Nighlife
# 1529                                      Gramercy Sunset
# 1530                               I'm a Fool to Want You
# ...

# %% [markdown]
# # what is the distribution of duration level in the dataset ? are there any outlier?

# %%
data.head()
# Out:
#    acousticness  danceability  duration_ms  energy  instrumentalness  key  \
# 0        0.0102         0.833       204600   0.434          0.021900    2
# 1        0.1990         0.743       326933   0.359          0.006110    1
# 2        0.0344         0.838       185707   0.412          0.000234    2
# 3        0.6040         0.494       199413   0.338          0.510000    5
# 4        0.1800         0.678       392893   0.561          0.512000    5
#
#    liveness  loudness  mode  speechiness    tempo  time_signature  valence  \
# 0    0.1650    -8.795     1       0.4310  150.062             4.0    0.286
# 1    0.1370   -10.401     1       0.0794  160.083             4.0    0.588
# 2    0.1590    -7.148     1       0.2890   75.044             4.0    0.173
# 3    0.0922   -15.236     1       0.0261   86.468             4.0    0.230
# 4    0.4390   -11.648     0       0.0694  174.004             4.0    0.904
#
#    target      song_title            artist
# ...

# %%
sns.histplot(data["duration_ms"])
# Out:
# <Axes: xlabel='duration_ms', ylabel='Count'>

# %%
q1 = data["duration_ms"].quantile(0.25)
q2 = data["duration_ms"].quantile(0.75)

iqr= q2 - q1

# %%
outlier =  data[(data ["duration_ms"] < q1 -1.5*iqr) | (data ["duration_ms"] > q2 + 1.5*iqr)]

# %%
print(f"no of the outlier = {len(outlier)}")
# Out:
# no of the outlier = 141

# %%
outlier["song_title"]
# Out:
# 4                               Parallel Lines
# 17                   One Nation Under a Groove
# 43                                     Monster
# 46                               Fantastic Man
# 49                      Odofo Nyi Akyiri Biara
#                          ...
# 1617    La Tromba Risin' (feat. Tasita D'Mour)
# 1644               Changes - Dirty South Remix
# 1653                               Skyscrapers
# 1944         (Everything I Do) I Do It For You
# 1948           Earth Song - Remastered Version
# Name: song_title, Length: 141, dtype: object

# %% [markdown]
# #what is the coerrelation between loudness and energy in the dataset?

# %%
data.corr()
# Out:
# <ipython-input-103-c44ded798807>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                   acousticness  danceability  duration_ms    energy  \
# acousticness          1.000000     -0.179894     0.071536 -0.646319
# danceability         -0.179894      1.000000     0.004695  0.038557
# duration_ms           0.071536      0.004695     1.000000 -0.144473
# energy               -0.646319      0.038557    -0.144473  1.000000
# instrumentalness      0.144397     -0.130561     0.305403 -0.122890
# key                  -0.081037      0.022325     0.023570  0.072886
# liveness             -0.117126     -0.132044     0.023203  0.217435
# loudness             -0.562021      0.104362    -0.273798  0.762177
# mode                  0.068028     -0.047867    -0.074806 -0.070263
# ...

# %%
sns.scatterplot(data=data,x='energy',y='loudness',hue='target')
# Out:
# <Axes: xlabel='energy', ylabel='loudness'>

# %% [markdown]
# # ans = when the loudness increase the energy also increase

# %% [markdown]
# #what are the most common keys and modes in the dataset?

# %%
data.head()
# Out:
#    acousticness  danceability  duration_ms  energy  instrumentalness  key  \
# 0        0.0102         0.833       204600   0.434          0.021900    2
# 1        0.1990         0.743       326933   0.359          0.006110    1
# 2        0.0344         0.838       185707   0.412          0.000234    2
# 3        0.6040         0.494       199413   0.338          0.510000    5
# 4        0.1800         0.678       392893   0.561          0.512000    5
#
#    liveness  loudness  mode  speechiness    tempo  time_signature  valence  \
# 0    0.1650    -8.795     1       0.4310  150.062             4.0    0.286
# 1    0.1370   -10.401     1       0.0794  160.083             4.0    0.588
# 2    0.1590    -7.148     1       0.2890   75.044             4.0    0.173
# 3    0.0922   -15.236     1       0.0261   86.468             4.0    0.230
# 4    0.4390   -11.648     0       0.0694  174.004             4.0    0.904
#
#    target      song_title            artist
# ...

# %%
data["key"].value_counts()
# Out:
# 1     257
# 0     216
# 7     212
# 9     191
# 11    187
# 2     184
# 5     166
# 6     159
# 10    141
# 8     136
# 4     105
# 3      63
# Name: key, dtype: int64

# %%
data["mode"].value_counts()
# Out:
# 1    1235
# 0     782
# Name: mode, dtype: int64

# %%
data.groupby(['key','mode']).size().reset_index(name="count")
# Out:
#     key  mode  count
# 0     0     0     49
# 1     0     1    167
# 2     1     0     82
# 3     1     1    175
# 4     2     0     33
# 5     2     1    151
# 6     3     0     21
# 7     3     1     42
# 8     4     0     52
# 9     4     1     53
# 10    5     0     89
# 11    5     1     77
# 12    6     0     79
# 13    6     1     80
# 14    7     0     55
# 15    7     1    157
# 16    8     0     46
# 17    8     1     90
# 18    9     0     83
# 19    9     1    108
# 20   10     0     84
# 21   10     1     57
# 22   11     0    109
# 23   11     1     78

# %%
keymode = data.groupby(['key','mode']).size().reset_index(name="count")# saving in a variable

# %%
sns.barplot(x='key',y='count',hue='mode',data=keymode)
# Out:
# <Axes: xlabel='key', ylabel='count'>

# %% [markdown]
# #what are the top 10 instrumental tracks?

# %%
data.head()
# Out:
#    acousticness  danceability  duration_ms  energy  instrumentalness  key  \
# 0        0.0102         0.833       204600   0.434          0.021900    2
# 1        0.1990         0.743       326933   0.359          0.006110    1
# 2        0.0344         0.838       185707   0.412          0.000234    2
# 3        0.6040         0.494       199413   0.338          0.510000    5
# 4        0.1800         0.678       392893   0.561          0.512000    5
#
#    liveness  loudness  mode  speechiness    tempo  time_signature  valence  \
# 0    0.1650    -8.795     1       0.4310  150.062             4.0    0.286
# 1    0.1370   -10.401     1       0.0794  160.083             4.0    0.588
# 2    0.1590    -7.148     1       0.2890   75.044             4.0    0.173
# 3    0.0922   -15.236     1       0.0261   86.468             4.0    0.230
# 4    0.4390   -11.648     0       0.0694  174.004             4.0    0.904
#
#    target      song_title            artist
# ...

# %%
instrumentalness=data["instrumentalness"].sort_values(ascending=False)[:10]

# %%
instrumentalness
# Out:
# 1313    0.976
# 271     0.968
# 1575    0.964
# 1619    0.958
# 725     0.957
# 1546    0.956
# 1322    0.955
# 1349    0.954
# 1661    0.954
# 121     0.952
# Name: instrumentalness, dtype: float64

# %%
song = data.loc[instrumentalness.index][["song_title","instrumentalness"]]

# %%
song
# Out:
#                                 song_title  instrumentalness
# 1313                       Senseless Order             0.976
# 271   So Destroyed (channeling Rage Peace)             0.968
# 1575             A Hundred Dreams from Now             0.964
# 1619                                 Raven             0.958
# 725                      Strandbar (disko)             0.957
# 1546                        Almas vaggvisa             0.956
# 1322                            Pitchblack             0.955
# 1349                       Prismatic Abyss             0.954
# 1661                               Yebisah             0.954
# 121                         Chasing Heaven             0.952

# %%
plt.barh(song["song_title"],song["instrumentalness"])
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# #what are top 10 energetic song title?

# %%
energy = data["energy"].sort_values(ascending=False)[:10]

# %%
data.loc[energy.index][["song_title","energy"]]
# Out:
#                song_title  energy
# 1299        No Absolution   0.998
# 1322           Pitchblack   0.997
# 1297    A Darkened Gospel   0.994
# 1347           Unanswered   0.993
# 2015        First Contact   0.992
# 1680             Paranoia   0.992
# 1332      Beautiful Agony   0.992
# 1328  Down into the Abyss   0.991
# 1681                Hated   0.990
# 1296         Black Colors   0.990

# %% [markdown]
# #multiple feature plot based on the taget?

# %%
data.columns
# Out:
# Index(['acousticness', 'danceability', 'duration_ms', 'energy',
#        'instrumentalness', 'key', 'liveness', 'loudness', 'mode',
#        'speechiness', 'tempo', 'time_signature', 'valence', 'target',
#        'song_title', 'artist'],
#       dtype='object')

# %%
intrest=['acousticness', 'danceability', 'duration_ms', 'energy',
       'instrumentalness', 'key', 'liveness', 'loudness', 'mode',
       'speechiness', 'tempo', 'time_signature', 'valence', 'target']

# %%
for names in intrest:
  pos_data = data[data["target"]==1][names]
  neg_data = data[data["target"]==0][names]

  plt.figure(figsize=(12,7))

  sns.histplot(pos_data,bins=30,label="positive",color="green")
  sns.histplot(neg_data,bins=30,label="negative",color="red")
  plt.legend()
  plt.title(f"positive and negative histogfram plots for {names}")
